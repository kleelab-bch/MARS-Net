# %% [markdown]
# ## GPU Setting

# %% [markdown]
# Verify that GPU is selected. <br>
# You can select GPU by
# Edit -> Notebook settings -> Set Hardware Accelerator to GPU

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2019 NVIDIA Corporation
# Built on Sun_Jul_28_19:07:16_PDT_2019
# Cuda compilation tools, release 10.1, V10.1.243
# Mon Apr 12 15:56:09 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 418.87.00    Driver Version: 418.87.00    CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  TITAN RTX           Off  | 00000000:1A:00.0 Off |                  N/A |
# | 39%   32C    P0    64W / 280W |      0MiB / 24190MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  TITAN RTX           Off  | 00000000:68:00.0 Off |                  N/A |
# | 33%   37C    P0     1W / 280W |      0MiB / 24189MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Import Python packages

# %%
import gc
import numpy as np
import cv2
import os
import os.path
from tqdm import tqdm
from tensorflow.keras import backend as K
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import get_file

from PIL import Image
import requests
from io import BytesIO
from matplotlib.pyplot import imshow
# %matplotlib inline

K.set_image_data_format('channels_first')

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Activation, Add, Input, concatenate, Conv2D, MaxPooling2D,
AveragePooling2D, ZeroPadding2D, UpSampling2D, Cropping2D, Conv2DTranspose,BatchNormalization, Dropout, GaussianNoise,
GlobalAveragePooling2D, Dense, Flatten, ReLU)

# %% [markdown]
# # Example images and models

# %%
def get_first_frame_demo():
    url = 'https://github.com/kleelab-bch/MARS-Net/blob/master/assets/040119_PtK1_S01_01_phase_ROI2/img_all/040119_PtK1_S01_01_phase_ROI2_1_001.png?raw=true'
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    return img

imshow(get_first_frame_demo(), cmap='gray')

# %% [markdown]
# # Run trained model to segment phase contrast live cell movie

# %% [markdown]
# ## Code for data preprocessing

# %%
def to3channel(imgs):
    imgs_p = np.repeat(imgs, 3, axis=1)
    imgs_p = imgs_p.astype('float32')

    return imgs_p


def preprocess_output(imgs):
    imgs_p = imgs.astype('float32')
    imgs_p /= 255.  # scale masks to [0, 1]

    return imgs_p


def preprocess_input(imgs, std=None, mean=None):
    imgs_p = to3channel(imgs)
    if std is None:
        std = np.std(imgs_p)
    if mean is None:
        mean = np.mean(imgs_p)

    imgs_p -= mean
    imgs_p /= std

    return imgs_p

# %% [markdown]
# ## Code for data loading

# %%
class DataGenerator:
    def __init__(self, img_path, input_size, output_size, img_format = '.png'):
        self.img_path = img_path
        self.input_size = input_size
        self.output_size = output_size
        self.img_format = img_format

    def get_expanded_whole_frames(self):
        img_list = self.get_img_list()
        imgs, image_rows, image_cols = self.get_expanded_images(self.img_path, img_list)

        # ------------------- pre-processing images -------------------
        # std and mean from test set images
        
        mean_value = np.mean(img_list)
        std_value = np.std(img_list)
        print('mean: ', mean_value, '  std: ', std_value)

        imgs = imgs[:, np.newaxis, :, :]
        imgs = preprocess_input(imgs, std_value, mean_value)
        
        return imgs, img_list, image_cols, image_rows, self.col, self.row

    def get_img_list(self):
        img_list = []
        img_path = self.img_path
        
        url_list = []
        for frame_num in tqdm(range(1,200)):
          url = img_path + f'{frame_num:03d}.png?raw=true'
          response = requests.get(url)
          img = Image.open(BytesIO(response.content))
          img = np.asarray(img)
          img_list.append(img)
          if frame_num == 1:
            self.row, self.col = img.shape
        return img_list


    def get_expanded_images(self,img_path, img_list, ratio = 64.0):
        # expand test set images because our model only takes the image of size in ratio of 64
        imgs_row_exp = int(np.ceil(np.divide(self.row, ratio) ) * ratio)
        imgs_col_exp = int(np.ceil(np.divide(self.col, ratio) ) * ratio)

        # crop images that are not expanded enough
        # this is necessary to prevent boundary effect
        if (imgs_row_exp - self.row) < ratio:
            imgs_row_exp = imgs_row_exp + int(ratio)
            print('imgs_row_exp', imgs_row_exp)

        if (imgs_col_exp - self.col) < ratio:
            imgs_col_exp = imgs_col_exp + int(ratio)
            print('imgs_col_exp', imgs_col_exp)

        imgs = np.ndarray((len(img_list), int(imgs_row_exp), int(imgs_col_exp)), dtype=np.uint8) 
        print(imgs.shape)
        i = 0
        for img in img_list:
            imgs[i] = cv2.copyMakeBorder(img, 0, imgs_row_exp - self.row, 0, imgs_col_exp - self.col, cv2.BORDER_REFLECT)
            i += 1
        return imgs, imgs_row_exp, imgs_col_exp

# %% [markdown]
# ## Load an example movie comprised of 199 frames

# %%
img_path = 'https://github.com/kleelab-bch/MARS-Net/blob/master/assets/040119_PtK1_S01_01_phase_ROI2/img_all/040119_PtK1_S01_01_phase_ROI2_1_'
    
# ------------------- Data loading -------------------
prediction_data_generator = DataGenerator(img_path, 128, 68, img_format='.png')
expanded_img_list, orig_img_list, image_cols, image_rows, orig_cols, orig_rows = prediction_data_generator.get_expanded_whole_frames()

print('expanded_img_list:', image_rows, image_cols, expanded_img_list.dtype, expanded_img_list.shape)
print('orig img size:', orig_rows, orig_cols)
# Out:
# expanded_img_list: 768 768 float32 (199, 3, 768, 768)
# orig img size: 672 648 uint8 (672, 648)

# %% [markdown]
# ## Load Trained Models

# %%
def UNet(img_rows, img_cols, crop_margin, right_crop, bottom_crop, loaded_weights):
    inputs = Input((3, img_rows, img_cols))
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(1024, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([UpSampling2D(size=(2, 2))(conv5), conv4], axis=1)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), conv3], axis=1)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([UpSampling2D(size=(2, 2))(conv7), conv2], axis=1)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([UpSampling2D(size=(2, 2))(conv8), conv1], axis=1)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)
    if bottom_crop == 0:
        conv10 = Cropping2D(cropping=((crop_margin, crop_margin),(crop_margin, crop_margin)))(conv10) # ((top_crop, bottom_crop), (left_crop, right_crop)) for training
    else:
        conv10 = Cropping2D(cropping=((0, bottom_crop),(0, right_crop)))(conv10)  # remove reflected portion from the image for prediction

    model = Model(inputs=inputs, outputs=conv10)

    model.load_weights(loaded_weights, by_name=True)

    return model

def VGG19_dropout(img_rows, img_cols, crop_margin, right_crop, bottom_crop, loaded_weights):
    inputs = Input(shape=[3, img_rows, img_cols])
    # Block 1
    x = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv1')(inputs)
    block1_conv2 = Conv2D(64, (3, 3), activation='relu', padding='same', name='block1_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block1_pool')(block1_conv2)
    x = Dropout(0.25)(x)

    # Block 2
    x = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv1')(x)
    block2_conv2 = Conv2D(128, (3, 3), activation='relu', padding='same', name='block2_conv2')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block2_pool')(block2_conv2)
    x = Dropout(0.5)(x)

    # Block 3
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv1')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv2')(x)
    x = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv3')(x)
    block3_conv4 = Conv2D(256, (3, 3), activation='relu', padding='same', name='block3_conv4')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block3_pool')(block3_conv4)
    x = Dropout(0.5)(x)

    # Block 4
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv3')(x)
    block4_conv4 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block4_conv4')(x)
    x = MaxPooling2D((2, 2), strides=(2, 2), name='block4_pool')(block4_conv4)
    x = Dropout(0.5)(x)

    # Block 5
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv1')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv2')(x)
    x = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv3')(x)
    block5_conv4 = Conv2D(512, (3, 3), activation='relu', padding='same', name='block5_conv4')(x)


    # upsampling model
    up6 = concatenate([UpSampling2D(size=(2, 2))(block5_conv4), block4_conv4], axis=1)
    up6 = Dropout(0.5)(up6)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([UpSampling2D(size=(2, 2))(conv6), block3_conv4], axis=1)
    up7 = Dropout(0.5)(up7)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([UpSampling2D(size=(2, 2))(conv7), block2_conv2], axis=1)
    up8 = Dropout(0.5)(up8)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([UpSampling2D(size=(2, 2))(conv8), block1_conv2], axis=1)
    up9 = Dropout(0.5)(up9)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)
    if bottom_crop == 0:
        conv10 = Cropping2D(cropping=((crop_margin, crop_margin), (crop_margin, crop_margin)))(conv10)  # ((top_crop, bottom_crop), (left_crop, right_crop)) for training
    else:
        conv10 = Cropping2D(cropping=((0, bottom_crop), (0, right_crop)))(conv10)  # remove reflected portion from the image for prediction

    model = Model(inputs=inputs, outputs=conv10)

    # Load weights.
    model.load_weights(loaded_weights, by_name=True)

    return model

# %% [markdown]
# ### Single-Microscopy-Type U-Net

# %%
unet_weights = get_file(
        'unet_weights',
        'https://www.googleapis.com/drive/v3/files/1OlAL_B7mvVVfqpmI9IQxY1ozNkN1IXc8?alt=media&key=AIzaSyABWfW4p2eX_xxCQbzjZIbXWnYyZhanCe8')

UNet_model = UNet(image_rows, image_cols, 0, image_cols-orig_cols, image_rows-orig_rows, unet_weights)
print('model layers: ', len(UNet_model.layers))
# Out:
# model layers:  33

# %%
unet_output = UNet_model.predict(expanded_img_list, batch_size = 1, verbose = 1)
unet_output = 255 * unet_output  # 0=background and 255=foreground
unet_output = unet_output.astype('uint8')
K.clear_session()
# Out:
#   1/199 [..............................] - ETA: 0sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0138s vs `on_predict_batch_end` time: 0.0527s). Check your callbacks.
# 199/199 [==============================] - 13s 65ms/step

# %% [markdown]
# ### MARS-Net (Multiple-Microscopy-Type VGG19D-U-Net)

# %%
vgg19d_weights = get_file(
        'vgg19_weights',
        'https://www.googleapis.com/drive/v3/files/1zvNibXaJ58nImu31STYPDjqc1KF1Ei16?alt=media&key=AIzaSyABWfW4p2eX_xxCQbzjZIbXWnYyZhanCe8')

VGG19_dropout_model = VGG19_dropout(image_rows, image_cols, 0, image_cols-orig_cols, image_rows-orig_rows, vgg19d_weights)
print('model layers: ', len(VGG19_dropout_model.layers))
# Out:
# model layers:  47

# %%
VGG19_dropout_output = VGG19_dropout_model.predict(expanded_img_list, batch_size = 1, verbose = 1)
VGG19_dropout_output = 255 * VGG19_dropout_output  # 0=background and 255=foreground
VGG19_dropout_output = VGG19_dropout_output.astype('uint8')
K.clear_session()
# Out:
#   2/199 [..............................] - ETA: 6sWARNING:tensorflow:Callbacks method `on_predict_batch_end` is slow compared to the batch time (batch time: 0.0163s vs `on_predict_batch_end` time: 0.0596s). Check your callbacks.
# 199/199 [==============================] - 14s 71ms/step

# %% [markdown]
# ## Compare segmentation results (Single-Microscopy-Type U-Net vs. MARS-Net)

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(12,12) )
fig.suptitle('Segmentation on the first frame', fontsize=20)

ax1.imshow(unet_output[0, 0, :, :], cmap='gray')
ax1.set_title('U-Net', fontsize=16)

ax2.imshow(VGG19_dropout_output[0, 0, :, :], cmap='gray')
ax2.set_title('MARS-Net', fontsize=16)

first_frame = np.asarray(get_first_frame_demo())
ax3.imshow(first_frame, cmap='gray')
ax3.set_title('First Frame', fontsize=16)

plt.tight_layout()
plt.subplots_adjust(top=1.5)
plt.show()

# %% [markdown]
# ### Segmented Movie

# %%
from IPython.display import HTML
from base64 import b64encode
import matplotlib.cm as cm
import matplotlib.animation as animation

def make_gif_movie(filename, segmentation_result):
    frames = []
    fig = plt.figure(figsize=(12,12))
    for i in range(len(segmentation_result)):
        frames.append([plt.imshow(segmentation_result[i], cmap=cm.Greys_r,animated=True)])

    ani = animation.ArtistAnimation(fig, frames, interval=40, blit=True,
                                    repeat_delay=1000)
    ani.save(filename)
    

def show_gif_movie(filename):
    file = open(filename,'rb').read()
    data_url = "data:image/gif;base64," + b64encode(file).decode()
    HTML("""
    <img src=%s>
    """ % data_url)

# %%
filename='unet_segmentation_movie.gif'
make_gif_movie(filename, np.moveaxis(unet_output, 1, -1))
show_gif_movie(filename)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
filename='MARS_Net_segmentation_movie.gif'
make_gif_movie(filename, np.moveaxis(VGG19_dropout_output, 1, -1))
show_gif_movie(filename)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %% [markdown]
# ### Edge Overlay

# %%
# prepare orig image array
orig_img_array = np.asarray(orig_img_list)
orig_img_array = orig_img_array[:,np.newaxis,:,:]
orig_img_array = np.repeat(orig_img_array, 3, axis=1)
print(orig_img_array.shape)
# Out:
# (672, 648)
# (199, 672, 648)
# (199, 3, 672, 648)

# %%
unet_edge_list = []
vgg19d_edge_list = []

unet_edge_array = np.zeros(unet_output.shape).astype('uint8')
vgg19d_edge_array = np.zeros(VGG19_dropout_output.shape).astype('uint8')

for i in range(len(unet_output)):
    unet_edge_array[i] = cv2.Canny(unet_output[i,0,:,:], 100, 200)
    vgg19d_edge_array[i] = cv2.Canny(VGG19_dropout_output[i,0,:,:], 100, 200)

print(unet_edge_array.shape)
print(vgg19d_edge_array.shape)
# Out:
# (199, 1, 672, 648)
# (199, 1, 672, 648)

# %%
overlay_edge_array = orig_img_array.copy()

overlay_edge_array = overlay_edge_array * 0.5
for index in range(len(orig_img_array)):
    overlay_edge_array[index,1,:,:] = overlay_edge_array[index,1,:,:] + unet_edge_array[index]  
    overlay_edge_array[index,0,:,:] = overlay_edge_array[index,0,:,:] + vgg19d_edge_array[index]
    
# move first channel to last channel
overlay_edge_array = np.moveaxis(overlay_edge_array, 1, -1)
overlay_edge_array[overlay_edge_array>255] = 255
overlay_edge_array = overlay_edge_array.astype('uint8')

# %%
fig, ax1 = plt.subplots(figsize=(12,12))
plt.title('Edge Overlay (Red=MARS-Net, Green=U-Net)', fontsize=20)
plt.imshow(overlay_edge_array[0])

# %%
filename='MARS_Net_edge_overlay_movie.gif'
make_gif_movie(filename, overlay_edge_array)
show_gif_movie(filename)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
